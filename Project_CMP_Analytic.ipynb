# %% [markdown]
# <a href="https://colab.research.google.com/github/cml096/GoogleColabRepo/blob/master/Project_Cap_Analytic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importamos las librerias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %% [markdown]
# Run here!

# %%
df = pd.read_excel('Rendimiento CMP V2.xlsx', sheet_name='MinaMLC')

# %% [markdown]
# ## Cleaning and Analysis

# %% [markdown]
# Creamos nuestro dataset de trabajo

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3138 entries, 0 to 3137
# Data columns (total 22 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Dia                                       3138 non-null   datetime64[ns]
#  1   Turno                                     3138 non-null   int64
#  2   Equipo                                    3138 non-null   int64
#  3   Cargas (u)                                3138 non-null   int64
#  4   Movimiento (t)                            3138 non-null   float64
#  5   tefe (seg)                                3138 non-null   int64
#  6   tdem (seg)                                3138 non-null   int64
#  7   R-ef (t/h)                                3138 non-null   float64
#  8   Número de personal                        3138 non-null   int64
#  9   División de personal                      3138 non-null   object
#  10  Cod. División                             3138 non-null   int64
#  11  Subdivisión de personal                   3138 non-null   object
#  12  Cod. Subdivisión                          3138 non-null   int64
#  13  Grupo de personal                         3138 non-null   object
#  14  Unidad organizativa                       3138 non-null   object
#  15  Cod. Unidad                               3138 non-null   int64
#  16  Posición                                  3138 non-null   object
#  17  Cod. Posición                             3138 non-null   int64
#  18  Fecha de nacimiento                       3138 non-null   datetime64[ns]
#  19  Edad del empleado                         3138 non-null   int64
#  20  Fecha de alta                             3138 non-null   datetime64[ns]
#  21  Status empleado para Gestión tiempos per  3138 non-null   object
# dtypes: datetime64[ns](3), float64(2), int64(11), object(6)
# memory usage: 539.5+ KB

# %%
df.head()
# Out:
#          Dia  Turno  ...  Fecha de alta  Status empleado para Gestión tiempos per
# 0 2019-07-01      2  ...     2011-10-01           1 - Evaluación de tiempos, real
# 1 2019-07-01      2  ...     1997-03-19           1 - Evaluación de tiempos, real
# 2 2019-07-01      2  ...     2008-11-01        9 - Evaluación de tiempos, teórico
# 3 2019-07-01      2  ...     2019-04-15           1 - Evaluación de tiempos, real
# 4 2019-07-01      2  ...     1998-03-31           1 - Evaluación de tiempos, real
#
# [5 rows x 22 columns]

# %% [markdown]
# Diccionario

# %%
diccionario = pd.read_excel('Rendimiento CMP V2.xlsx', sheet_name='Diccionario')
diccionario
# Out:
#                                      Columna                                            Detalle
# 0                                        Dia       Refiere al día que se registro la actividad.
# 1                                      Turno  Son los 2 turnos que presentan en la faena que...
# 2                                     Equipo      Refiere al número de la maquina que utilizan.
# 3                                 Cargas (u)  Cantidad  de baldadas del equipo de maquinaria...
# 4                             Movimiento (t)        Cantidad de toneladas movidas en el turno.
# 5                                 tefe (seg)                      Tiempo efectivo en segundos.
# 6                                 tdem (seg)                      Tiempo de demora en segundos.
# 7                                 R-ef (t/h)              Toneladas efectivas movidas en horas.
# 8                         Número de personal                      Código único del trabajador.
# 9                       División de personal  Referencia en que sector valle pertenece el tr...
# 10                             Cod. División                           Código  único del valle.
# 11                   Subdivisión de personal  Hace referencia al proceso en que está referen...
# 12                          Cod. Subdivisión                   Código único de la subdivisión.
# 13                       Unidad organizativa   Unidad en que está designado dentro del proceso.
# 14                               Cod. Unidad                       Código único  de la unidad.
# 15                                  Posición           Cargo que desempeña dentro de la unidad.
# 16                             Cod. Posición                         Código único de posición.
# 17                       Fecha de nacimiento                Fecha de nacimiento del trabajador.
# 18                         Edad del empleado                   Edad que desempeña a esa fecha.
# 19                             Fecha de alta  Registro de fecha en el cual ingresó a trabaja...
# 20  Status empleado para Gestión tiempos per  Forma en que se evalua su desempeño en la unid...

# %% [markdown]
# Dividimos Los procesos por zonas

# %%
proceso_valle_huasco = {
    'Mina' : ['Carguio Y transporte','Planificacion CP','Mantenimiento mina'],
    'Planta MLC' : ['Chancado','Concentracion Magnetica','Acopio','Mantenimiento Planta'],
    'Transporte' : ['Carga','Cargui'],
    'Planta Pellets' : ['Molienda','Concentracion Magnetica','Filtrado','Balling','Endurecimiento Termino','Mantenimiento PP'],
    'Embarque' : ['Recepcion','Embarque','Mantenimiento PP']
}
proceso_valle_elqui = {
    'Mina' : ['Carguio y transporte','Mantenimiento mina','Planificacion'],
    'Planta' : ['Chancado','Molienda','Concentracion Magnetica','Filtrado','Mantenimiento Planta'],
    'Transporte' : ['Receptor Y Acopio','Carguio','Transporte','Descarga','Mantenimiento Transporte'],
    'Embarque' : ['Recepcion y apilamiento','Embarque','Mantenimiento Puerto']
}
proceso_de_copiapo = {
    'Mina' : ['Carguio Y transporte','Planificacion CP'],
    'Planta CNN' : ['Chancado','Molienda','Concentracion Magnetica','Mantenimiento Planta CNN'],
    'Planta Magnetica' : ['Molienda','Concentracion Magnetica','Mantenimiento Planta Magnetica'],
    'Transporte Fluido' : ['Transporte Fluido CNN','Relave','Mantenimiento PM','Integridad de Ducto'],
    'Filtrado' : ['Filtrado'],
    'Embarque' : ['Recepcion Y Apilamiento']
}

# %% [markdown]
# ## Group by personal division

# %%
df_ = df.drop(['Turno','Equipo','Número de personal','Cod. División','Cod. Subdivisión','Cod. Unidad','Cod. Posición'], axis=1)
df_.groupby(['División de personal']).mean()
# Out:
#                       Cargas (u)  ...  Edad del empleado
# División de personal              ...
# CMP VALLE DEL ELQUI    85.157895  ...          38.000000
# CMP VALLE DEL HUASCO   63.912151  ...          45.271241
#
# [2 rows x 6 columns]

# %% [markdown]
# ## Group by personal subdivision

# %% [markdown]
# Tomaremos división CMP VALLE DEL HUASCO

# %%
df_ = df.drop(['Turno','Equipo','Número de personal','Cod. División','Cod. Subdivisión','Cod. Unidad','Cod. Posición'], axis=1)
df_.groupby(['Subdivisión de personal']).mean()
# Out:
#                          Cargas (u)  ...  Edad del empleado
# Subdivisión de personal              ...
# MINA LOS COLORA           65.164384  ...          45.528219
# MINA ROMERAL              85.157895  ...          38.000000
# OFICINA GENERAL           83.733333  ...          38.746667
# PLANTA PELLETS            60.817884  ...          45.287941
#
# [4 rows x 6 columns]

# %% [markdown]
# # Personal division MINA LOS COLORA

# %% [markdown]
# filtro MINA LOS COLORADOS

# %%
df_test_minera_colorado = df[df['Subdivisión de personal'] == 'MINA LOS COLORA']

# %% [markdown]
# filtro CMP VALLE DEL HUASCO

# %%
df_test_minera_colorado = df_test_minera_colorado[df_test_minera_colorado['División de personal'] == 'CMP VALLE DEL HUASCO']

# %%
df_ = df_test_minera_colorado
filtro = ['Turno','Equipo','Número de personal','Cod. División','Cod. Subdivisión','Cod. Unidad','Cod. Posición']
df_.drop(filtro, axis=1).describe()
# Out:
#         Cargas (u)  Movimiento (t)  ...   R-ef (t/h)  Edad del empleado
# count  1825.000000     1825.000000  ...  1825.000000        1825.000000
# mean     65.164384    15089.483905  ...  2422.582727          45.528219
# std      41.631863     9665.474818  ...   813.882872          11.608631
# min       1.000000      216.899990  ...   279.603580          26.000000
# 25%      31.000000     7210.500120  ...  1808.232502          34.000000
# 50%      61.000000    14138.999020  ...  2355.800564          48.000000
# 75%      94.000000    21434.798830  ...  3014.188792          57.000000
# max     213.000000    50036.500000  ...  6322.608522          64.000000
#
# [8 rows x 6 columns]

# %% [markdown]
# Creamos un array que contiene las tefe max de cada Unidad organizativa

# %%
filtro = ['Dia','División de personal',	'Subdivisión de personal','Grupo de personal','Posición',	'Fecha de nacimiento','Edad del empleado','Fecha de alta','Status empleado para Gestión tiempos per']
group = df_.drop(filtro, axis=1).groupby(['Unidad organizativa']).max()
df_group = pd.DataFrame(group)

# %%
max_por_unidad = []
for index, row in df_group.iterrows():
  max_por_unidad.append([index,row['tefe (seg)']])

# %% [markdown]
# Agregamos la columna "Eficiencia" que generaremos con la furmula de = tefe(x tupla)*100/tefe_max

# %%
df_ = df_test_minera_colorado
eficiencia = []
for index, row in df_.iterrows():
  unidad = row['Unidad organizativa']
  tefe = row['tefe (seg)']
  for unidad_max,tefe_max in max_por_unidad:
    if unidad == unidad_max:
      resultado = (tefe)/tefe_max
      eficiencia.append(resultado)
df_['Eficiencia'] = eficiencia

# %%
df_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1825 entries, 0 to 3137
# Data columns (total 23 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Dia                                       1825 non-null   datetime64[ns]
#  1   Turno                                     1825 non-null   int64
#  2   Equipo                                    1825 non-null   int64
#  3   Cargas (u)                                1825 non-null   int64
#  4   Movimiento (t)                            1825 non-null   float64
#  5   tefe (seg)                                1825 non-null   int64
#  6   tdem (seg)                                1825 non-null   int64
#  7   R-ef (t/h)                                1825 non-null   float64
#  8   Número de personal                        1825 non-null   int64
#  9   División de personal                      1825 non-null   object
#  10  Cod. División                             1825 non-null   int64
#  11  Subdivisión de personal                   1825 non-null   object
#  12  Cod. Subdivisión                          1825 non-null   int64
#  13  Grupo de personal                         1825 non-null   object
#  14  Unidad organizativa                       1825 non-null   object
#  15  Cod. Unidad                               1825 non-null   int64
#  16  Posición                                  1825 non-null   object
#  17  Cod. Posición                             1825 non-null   int64
#  18  Fecha de nacimiento                       1825 non-null   datetime64[ns]
#  19  Edad del empleado                         1825 non-null   int64
#  20  Fecha de alta                             1825 non-null   datetime64[ns]
#  21  Status empleado para Gestión tiempos per  1825 non-null   object
#  22  Eficiencia                                1825 non-null   float64
# dtypes: datetime64[ns](3), float64(3), int64(11), object(6)
# memory usage: 342.2+ KB

# %% [markdown]
# Generamos 2 funciones para separa lo que es la variable Dia en mes y año

# %%
def mes(fecha):
  aux = str(fecha.date()).split('-')
  mes = str(aux[1])
  return mes

def ano(fecha):
  aux = str(fecha.date()).split('-')
  ano = str(aux[0])
  return ano

# %% [markdown]
# Aplicamos las funciones y creamos una nueva columna

# %%
df_['Mes'] = df_.apply(lambda row : mes(row['Dia']),axis=1)
df_['Año'] = df_.apply(lambda row : ano(row['Dia']),axis=1)

# %%
df_2019 = df_[df_['Año'] == '2019'] 
df_2020 = df_[df_['Año'] == '2020']

# %%
df_mes_2019 = df_2019[df_2019['Mes'] == '08']
x = df_mes_2019['Dia']
y = df_mes_2019['Eficiencia']
data = df_mes_2019
plt.figure(figsize=(20,8))
sns.lineplot( x=x, y=y,data=data,err_style='bars',color="coral")

# %%
df_2019.groupby("Mes").mean()
# Out:
#         Turno      Equipo  ...  Edad del empleado  Eficiencia
# Mes                        ...
# 07   1.522523  248.027027  ...          44.630631    0.553672
# 08   1.497630  258.075829  ...          44.928910    0.551230
# 09   1.512195  242.408537  ...          43.859756    0.576933
# 10   1.554140  239.585987  ...          44.184713    0.553130
# 11   1.493421  248.690789  ...          43.098684    0.534436
# 12   1.464646  248.989899  ...          45.737374    0.536864
#
# [6 rows x 14 columns]

# %%
df_2019.groupby("Dia").mean()
# Out:
#                Turno      Equipo  ...  Edad del empleado  Eficiencia
# Dia                               ...
# 2019-07-01  2.000000  243.666667  ...          48.333333    0.517927
# 2019-07-02  1.428571  239.000000  ...          44.428571    0.588158
# 2019-07-03  1.571429  225.000000  ...          44.714286    0.625283
# 2019-07-04  1.500000  223.500000  ...          43.250000    0.552769
# 2019-07-05  1.625000  270.375000  ...          48.875000    0.408712
# ...              ...         ...  ...                ...         ...
# 2019-12-27  1.400000  229.800000  ...          43.400000    0.623830
# 2019-12-28  1.571429  225.000000  ...          43.285714    0.488967
# 2019-12-29  1.444444  232.333333  ...          42.666667    0.512843
# 2019-12-30  1.428571  238.428571  ...          41.714286    0.575222
# 2019-12-31  1.600000  239.800000  ...          46.300000    0.430852
#
# [177 rows x 14 columns]

# %% [markdown]
# ##Analizing "equipo"

# %% [markdown]
# Analizaremos por personal por Equipo

# %%
df_ = df_test_minera_colorado
df_210 = df_[df_['Equipo'] == 210]
equipo_210 = df_210['Número de personal'].count()
df_211 = df_[df_['Equipo'] == 211]
equipo_211 = df_211['Número de personal'].count()
df_212 = df_[df_['Equipo'] == 212]
equipo_212 = df_212['Número de personal'].count()
df_213 = df_[df_['Equipo'] == 213]
equipo_213 = df_213['Número de personal'].count()
df_305 = df_[df_['Equipo'] == 305]
equipo_305 = df_305['Número de personal'].count()
df_306 = df_[df_['Equipo'] == 306]
equipo_306 = df_306['Número de personal'].count()
df_307 = df_[df_['Equipo'] == 307]
equipo_307 = df_307['Número de personal'].count()
print(f'Equpos : Cantidad')
print(f'210 : {equipo_210}')
print(f'211 : {equipo_211}')
print(f'212 : {equipo_212}')
print(f'213 : {equipo_213}')
print(f'305 : {equipo_305}')
print(f'306 : {equipo_306}')
print(f'307 : {equipo_307}')
# Out:
# Equpos : Cantidad
# 210 : 278
# 211 : 365
# 212 : 53
# 213 : 253
# 305 : 232
# 306 : 266
# 307 : 378

# %% [markdown]
# Cantidad de personal por equipo

# %%
filtro = ['Turno','Número de personal','Cod. División','Cod. Subdivisión','Cod. Unidad','Cod. Posición']
groupby = df_.drop(filtro, axis=1).groupby(['Equipo']).mean()
groupby
# Out:
#         Cargas (u)  Movimiento (t)  ...   R-ef (t/h)  Edad del empleado
# Equipo                              ...
# 210      73.248201    17166.864908  ...  2831.360153          39.852518
# 211      84.506849    19385.251074  ...  2949.534153          39.873973
# 212      91.792453    21374.928664  ...  3640.441281          43.471698
# 213      88.438735    20567.788843  ...  3164.869376          41.818182
# 305      30.780172     7073.821147  ...  1428.569405          47.534483
# 306      49.124060    11377.678627  ...  1915.676094          49.748120
# 307      53.621693    12397.333925  ...  1912.333612          53.732804
#
# [7 rows x 6 columns]

# %% [markdown]
# Analizamos las variables por equipo de trabajo

# %%
filtro = ['Turno','Equipo','División de personal','Subdivisión de personal','Número de personal','Cod. División','Cod. Subdivisión','Cod. Unidad','Cod. Posición','Fecha de alta','Fecha de nacimiento','Edad del empleado']
test = df_210.drop(filtro,axis=1)
print('Equipo 210')
test.corr()
# Out:
# Equipo 210
#                 Cargas (u)  Movimiento (t)  tefe (seg)  tdem (seg)  R-ef (t/h)
# Cargas (u)        1.000000        0.999448    0.946231    0.255472    0.360645
# Movimiento (t)    0.999448        1.000000    0.943903    0.253156    0.366540
# tefe (seg)        0.946231        0.943903    1.000000    0.303678    0.090450
# tdem (seg)        0.255472        0.253156    0.303678    1.000000   -0.054604
# R-ef (t/h)        0.360645        0.366540    0.090450   -0.054604    1.000000

# %% [markdown]
# Tomamos el equipo 210 para ver las correlaciones que se tienen

# %%
sns.pairplot(test)

# %% [markdown]
# ##Boxplot "equipo vs 4 variables"

# %%
y = ['Cargas (u)','Movimiento (t)','tefe (seg)','tdem (seg)','R-ef (t/h)']
for y_ in y:
  plt.figure(figsize=(15,5))
  sns.boxplot(x='Equipo',y=y_,data=df_test_minera_colorado).set_title(y_)

# %% [markdown]
# Scatter plot "diferencia entre equipos"
# * movimiento vs tiempo efectivo

# %%
equipos = [[df_210,'Equipo 210','#3349FF'],
           [df_211,'Equipo 211','#FFD433'],
           [df_212,'Equipo 212','#17A301'],
           [df_213,'Equipo 213','#FF0000'],
           [df_305,'Equipo 305','#BC10EF'],
           [df_306,'Equipo 306','#784100'],
           [df_307,'Equipo 307','#FF33D7']]
plt.figure(figsize=(15,5))
for equipo,nombre,color in equipos:
  sns.scatterplot(equipo['Movimiento (t)'], equipo['tefe (seg)'], label=nombre, color=color, alpha=0.5)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.regplot( x=df_test_minera_colorado['Movimiento (t)'], y=df_test_minera_colorado['tefe (seg)'],data=df_test_minera_colorado)

# %% [markdown]
# ##Test Regresion Lineal

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# Generamos variables de entrenamiento y test
# *

# %%
df_ = df_test_minera_colorado
X = df_[['Movimiento (t)','Cargas (u)']]
y = df_['tefe (seg)']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)

# %%
from sklearn import linear_model

# %% [markdown]
# Creamos nuestra regresion lineal y hacemo el fit

# %%
modelo = linear_model.LinearRegression()
modelo.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# Prediction

# %%
y_pred = modelo.predict(X_test)

# %%
print(f'Termino independiente (b): {modelo.intercept_}')
# Out:
# Termino independiente (b): 7103.706890309217

# %%
coef = pd.DataFrame(modelo.coef_,X.columns,columns=['Coefficient'])
coef
# Out:
#                 Coefficient
# Movimiento (t)    -0.153404
# Cargas (u)       259.057580

# %% [markdown]
# **Duda acá!!!!**
# mientras la variación de una unidad de la variable tefem (seg)

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(y_test,y_pred,color='blue',alpha=0.5)

# %% [markdown]
# Residuales

# %%
sns.distplot((y_test-y_pred),bins=50);

# %% [markdown]
# Error cuadrático medio

# %%
from sklearn import metrics
print(f'Error Cuadrático Medio: {metrics.mean_squared_error(y_test,y_pred)}')
# Out:
# Error Cuadrático Medio: 34524959.93443971

# %% [markdown]
# esta malisimo! muy grande :c

# %% [markdown]
# ## Anilyzing "turno"

# %% [markdown]
# filtos ocupados para la realizacion del análisis
# * division CMP VALLE HUASCO
# * subdivision MINA LOS COLORADOS

# %%
filtro = ['Equipo','Dia','Mes','Año','Número de personal','Eficiencia (bin)']
sns.pairplot(df_.drop(filtro,axis=1), hue='Turno', palette='Set2')

# %%
df_turno_1 = df_test_minera_colorado[df_test_minera_colorado['Turno'] == 1]
df_turno_2 = df_test_minera_colorado[df_test_minera_colorado['Turno'] == 2]

# %%
filtro = ['Turno','Número de personal','Cod. División','Subdivisión de personal','Cod. Subdivisión','Grupo de personal','Cod. Unidad','Cod. Posición','Fecha de nacimiento','Edad del empleado','Status empleado para Gestión tiempos per']
df_test = df_turno_1.drop(filtro,axis=1)
df_test.head(7)
# Out:
#           Dia  Equipo  ...                      Posición  Fecha de alta
# 5  2019-07-02     211  ...                  OPERADOR III     2013-09-01
# 6  2019-07-02     213  ...                  MECANICO III     2011-04-01
# 7  2019-07-02     213  ...  OPERADOR MECANICO III PLANTA     2013-03-01
# 8  2019-07-02     305  ...                   ELECTRICO I     1996-12-17
# 15 2019-07-03     210  ...  OPERADOR MECANICO III PLANTA     2013-03-01
# 16 2019-07-03     211  ...                  OPERADOR III     2013-09-01
# 17 2019-07-03     213  ...  OPERADOR MECANICO III PLANTA     2013-03-01
#
# [7 rows x 11 columns]

# %%
filtro = ['Turno','Número de personal','Cod. División','Subdivisión de personal','Cod. Subdivisión','Grupo de personal','Cod. Unidad','Cod. Posición','Fecha de nacimiento','Edad del empleado','Status empleado para Gestión tiempos per']
df_test = df_turno_2.drop(filtro,axis=1)
df_test.head(7)
# Out:
#           Dia  Equipo  ...                      Posición  Fecha de alta
# 0  2019-07-01     211  ...                 ELECTRICO III     2011-10-01
# 1  2019-07-01     213  ...                    MECANICO I     1997-03-19
# 4  2019-07-01     307  ...  OPERADOR ELECTRICO II PLANTA     1998-03-31
# 11 2019-07-02     211  ...                    OPERADOR I     2013-11-01
# 12 2019-07-02     213  ...                    MECANICO I     1997-03-19
# 14 2019-07-02     307  ...  OPERADOR ELECTRICO II PLANTA     1998-03-31
# 20 2019-07-03     210  ...                    MECANICO I     1997-03-19
#
# [7 rows x 11 columns]

# %%
filtro = filtro = ['Turno','Número de personal','Cod. División','Cod. Subdivisión','Cod. Unidad','Cod. Posición']
df_test = df_turno_1.drop(filtro,axis=1)
df_test.groupby(['Dia']).mean().head()
# Out:
#                 Equipo  Cargas (u)  ...   R-ef (t/h)  Edad del empleado
# Dia                                 ...
# 2019-07-02  235.500000   58.750000  ...  2310.589743          40.000000
# 2019-07-03  211.333333   99.000000  ...  3428.837043          33.666667
# 2019-07-04  211.750000   95.500000  ...  3231.287790          33.500000
# 2019-07-05  243.333333   53.333333  ...  2674.959126          39.333333
# 2019-07-06  243.000000  110.333333  ...  2902.698556          41.666667
#
# [5 rows x 7 columns]

# %%
filtro = filtro = ['Turno','Número de personal','Cod. División','Cod. Subdivisión','Cod. Unidad','Cod. Posición']
df_test = df_turno_2.drop(filtro,axis=1)
df_test.groupby(['Dia']).mean().head()
# Out:
#                 Equipo  Cargas (u)  ...   R-ef (t/h)  Edad del empleado
# Dia                                 ...
# 2019-07-01  243.666667   68.333333  ...  2579.443660          48.333333
# 2019-07-02  243.666667   97.333333  ...  2634.643696          50.333333
# 2019-07-03  235.250000   88.500000  ...  2721.299028          53.000000
# 2019-07-04  235.250000   72.250000  ...  3088.237107          53.000000
# 2019-07-05  286.600000   35.400000  ...  1778.006633          54.600000
#
# [5 rows x 7 columns]

# %%
df_test = df_turno_2[df_turno_2['Dia'] == '2019-07-01']
df_test.drop(filtro,axis=1)
# Out:
#          Dia  Equipo  ...                      Posición  Fecha de alta
# 0 2019-07-01     211  ...                 ELECTRICO III     2011-10-01
# 1 2019-07-01     213  ...                    MECANICO I     1997-03-19
# 4 2019-07-01     307  ...  OPERADOR ELECTRICO II PLANTA     1998-03-31
#
# [3 rows x 11 columns]

# %%
df_test = df_turno_2[df_turno_2['Dia'] == '2019-08-20']
df_test.drop(filtro,axis=1)
# Out:
#            Dia  Equipo  ...                      Posición  Fecha de alta
# 595 2019-08-20     211  ...                    OPERADOR I     2013-11-01
# 597 2019-08-20     213  ...                    MECANICO I     1997-03-19
# 601 2019-08-20     307  ...  OPERADOR ELECTRICO II PLANTA     1998-03-31
#
# [3 rows x 11 columns]

# %%
df_test = df_turno_1[df_turno_1['Dia'] == '2019-07-02']
df_test.drop(filtro,axis=1)
# Out:
#          Dia  Equipo  ...                      Posición  Fecha de alta
# 5 2019-07-02     211  ...                  OPERADOR III     2013-09-01
# 6 2019-07-02     213  ...                  MECANICO III     2011-04-01
# 7 2019-07-02     213  ...  OPERADOR MECANICO III PLANTA     2013-03-01
# 8 2019-07-02     305  ...                   ELECTRICO I     1996-12-17
#
# [4 rows x 11 columns]

# %%
df_test = df_turno_1[df_turno_1['Dia'] == '2019-08-02']
df_test.drop(filtro,axis=1)
# Out:
#            Dia  Equipo  ...                      Posición  Fecha de alta
# 382 2019-08-02     212  ...                  MECANICO III     2011-04-01
# 383 2019-08-02     212  ...  OPERADOR MECANICO III PLANTA     2013-03-01
# 384 2019-08-02     305  ...                   ELECTRICO I     1996-12-17
#
# [3 rows x 11 columns]

# %% [markdown]
# ## Analizing of variable "Dia"

# %% [markdown]
# filtos ocupados para la realizacion del análisis
# * division CMP VALLE HUASCO
# * subdivision MINA LOS COLORADOS

# %%
df_ = df_test_minera_colorado

# %%
df_.groupby('Dia').mean()
# Out:
#                Turno      Equipo  ...  Edad del empleado       Test
# Dia                               ...
# 2019-07-01  2.000000  243.666667  ...          48.333333  51.792746
# 2019-07-02  1.428571  239.000000  ...          44.428571  58.815773
# 2019-07-03  1.571429  225.000000  ...          44.714286  62.528344
# 2019-07-04  1.500000  223.500000  ...          43.250000  55.276947
# 2019-07-05  1.625000  270.375000  ...          48.875000  40.871169
# ...              ...         ...  ...                ...        ...
# 2020-06-18  1.666667  242.333333  ...          47.666667  44.022202
# 2020-06-19  1.500000  258.000000  ...          42.250000  44.507077
# 2020-06-20  1.500000  259.500000  ...          50.000000  32.148443
# 2020-06-21  1.400000  250.200000  ...          45.800000  60.622766
# 2020-06-22  1.400000  249.800000  ...          45.800000  40.147898
#
# [342 rows x 14 columns]

# %%
plt.figure(figsize=(25,15))
sns.lineplot(x='Dia',y='Movimiento (t)',data=df_,color='blue', linestyle='dashed', marker='o',markerfacecolor='red', markersize=10)
